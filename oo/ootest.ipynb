# %%
import supervised_worker as sw

# %%
supervised = sw.SupervisedWorker("wdbc.data.mb.csv", header=False)

# %%
supervised.load_data_supervised()

# %%
supervised.zscore_normalize()

# %%
supervised.train_test_split(0.3, 42)

# %%
supervised.performKNN(3)

# %%
supervised.plotKNN(output="Show")
