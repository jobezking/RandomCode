# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
from scipy import stats
from scipy.stats import chi2_contingency
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
modeldata = pd.read_csv("/mnt/data/big_csv_files/output_csv_full.csv",low_memory=False) #load data

# %%
pd.set_option('future.no_silent_downcasting', True)

# %%
print(modeldata.head())
print(modeldata.tail())
# Out:
#    time_ref  account code country_code product_type        value status
# 0    202412  Exports   00           AD        Goods       2581.0      F
# 1    202412  Exports   00           AE        Goods  323384662.0      F
# 2    202412  Exports   00           AG        Goods     266255.0      F
# 3    202412  Exports   00           AI        Goods      11760.0      F
# 4    202412  Exports   00           AL        Goods     639168.0      F
#          time_ref  account    code country_code product_type     value status
# 2456285    201406  Imports  A12123           US     Services  168141.0      F
# 2456286    201406  Imports  A12123           VN     Services  112094.0      F
# 2456287    201406  Imports  A12123           VU     Services   56047.0      F
# 2456288    201406  Imports  A12123           WS     Services   56047.0      F
# 2456289    201406  Imports  A12123           ZA     Services   56047.0      F

# %%
modeldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2456290 entries, 0 to 2456289
# Data columns (total 7 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   time_ref      int64
#  1   account       object
#  2   code          object
#  3   country_code  object
#  4   product_type  object
#  5   value         float64
#  6   status        object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 131.2+ MB

# %%
print(f"Dataset contains {modeldata.shape[0]} rows and {modeldata.shape[1]} columns.\n")
# Out:
# Dataset contains 2456290 rows and 7 columns.

# %%
modeldata.describe()
# Out:
#            time_ref         value
# count  2.456290e+06  2.304323e+06
# mean   2.019189e+05  5.096921e+06
# std    3.096674e+02  1.655224e+08
# min    2.014060e+05 -1.616938e+09
# 25%    2.016120e+05  2.384000e+03
# 50%    2.019090e+05  2.205900e+04
# 75%    2.022060e+05  1.966490e+05
# max    2.024120e+05  2.409993e+10

# %%
print(modeldata['account'].describe()) #2 unique values. Can be hot coded
# Out:
# count     2456290
# unique          2
# top       Imports
# freq      1400991
# Name: account, dtype: object

# %%
modeldata_encoded = pd.get_dummies(modeldata, columns=['account'], drop_first=True) #encode account one hot
modeldata = pd.concat([modeldata, modeldata_encoded], axis=1) # merge unencoded and encoded dataframe
modeldata
# Out:
#          time_ref  account    code  country_code  product_type        value  \
# 0          202412  Exports      00            AD         Goods       2581.0
# 1          202412  Exports      00            AE         Goods  323384662.0
# 2          202412  Exports      00            AG         Goods     266255.0
# 3          202412  Exports      00            AI         Goods      11760.0
# 4          202412  Exports      00            AL         Goods     639168.0
# ...           ...      ...     ...           ...           ...          ...
# 2456285    201406  Imports  A12123            US      Services     168141.0
# 2456286    201406  Imports  A12123            VN      Services     112094.0
# 2456287    201406  Imports  A12123            VU      Services      56047.0
# 2456288    201406  Imports  A12123            WS      Services      56047.0
# 2456289    201406  Imports  A12123            ZA      Services      56047.0
#
#         status  time_ref    code  country_code  ... status  time_ref    code  \
# 0            F    202412      00            AD  ...      F    202412      00
# 1            F    202412      00            AE  ...      F    202412      00
# 2            F    202412      00            AG  ...      F    202412      00
# 3            F    202412      00            AI  ...      F    202412      00
# 4            F    202412      00            AL  ...      F    202412      00
# ...        ...       ...     ...           ...  ...    ...       ...     ...
# 2456285      F    201406  A12123            US  ...      F    201406  A12123
# 2456286      F    201406  A12123            VN  ...      F    201406  A12123
# 2456287      F    201406  A12123            VU  ...      F    201406  A12123
# 2456288      F    201406  A12123            WS  ...      F    201406  A12123
# 2456289      F    201406  A12123            ZA  ...      F    201406  A12123
#
#          country_code  product_type        value status account_Imports  \
# 0                  AD         Goods       2581.0      F           False
# 1                  AE         Goods  323384662.0      F           False
# 2                  AG         Goods     266255.0      F           False
# 3                  AI         Goods      11760.0      F           False
# 4                  AL         Goods     639168.0      F           False
# ...               ...           ...          ...    ...             ...
# 2456285            US      Services     168141.0      F            True
# 2456286            VN      Services     112094.0      F            True
# 2456287            VU      Services      56047.0      F            True
# 2456288            WS      Services      56047.0      F            True
# 2456289            ZA      Services      56047.0      F            True
#
#         account_Imports account_Imports
# 0                 False           False
# 1                 False           False
# 2                 False           False
# 3                 False           False
# 4                 False           False
# ...                 ...             ...
# 2456285            True            True
# 2456286            True            True
# 2456287            True            True
# 2456288            True            True
# 2456289            True            True
#
# [2456290 rows x 56 columns]

# %%
print(modeldata['code'].describe()) #1407 unique values. Cannot be hotcoded
# Out:
#            code     code     code     code     code     code     code     code
# count   2456290  2456290  2456290  2456290  2456290  2456290  2456290  2456290
# unique     1407     1407     1407     1407     1407     1407     1407     1407
# top          00       00       00       00       00       00       00       00
# freq      17915    17915    17915    17915    17915    17915    17915    17915

# %%
print(modeldata['country_code'].describe()) #251 unique values. Cannot be hotcoded
# Out:
#        country_code country_code country_code country_code country_code  \
# count       2454712      2454712      2454712      2454712      2454712
# unique          251          251          251          251          251
# top              AU           AU           AU           AU           AU
# freq          93778        93778        93778        93778        93778
#
#        country_code country_code country_code
# count       2454712      2454712      2454712
# unique          251          251          251
# top              AU           AU           AU
# freq          93778        93778        93778

# %%
print(modeldata['product_type'].describe()) #2 unique values. Can be hot coded
# Out:
#        product_type product_type product_type product_type product_type  \
# count       2456290      2456290      2456290      2456290      2456290
# unique            2            2            2            2            2
# top           Goods        Goods        Goods        Goods        Goods
# freq        2179965      2179965      2179965      2179965      2179965
#
#        product_type product_type product_type
# count       2456290      2456290      2456290
# unique            2            2            2
# top           Goods        Goods        Goods
# freq        2179965      2179965      2179965

# %%
modeldata_encoded = pd.get_dummies(modeldata, columns=['product_type'], drop_first=True) #encode product type one hot
modeldata = pd.concat([modeldata, modeldata_encoded], axis=1) # merge unencoded and encoded dataframe
modeldata
# Out:
#          time_ref  account    code country_code product_type        value  \
# 0          202412  Exports      00           AD        Goods       2581.0
# 1          202412  Exports      00           AE        Goods  323384662.0
# 2          202412  Exports      00           AG        Goods     266255.0
# 3          202412  Exports      00           AI        Goods      11760.0
# 4          202412  Exports      00           AL        Goods     639168.0
# ...           ...      ...     ...          ...          ...          ...
# 2456285    201406  Imports  A12123           US     Services     168141.0
# 2456286    201406  Imports  A12123           VN     Services     112094.0
# 2456287    201406  Imports  A12123           VU     Services      56047.0
# 2456288    201406  Imports  A12123           WS     Services      56047.0
# 2456289    201406  Imports  A12123           ZA     Services      56047.0
#
#         status  time_ref    code country_code  ...  account_Imports  \
# 0            F    202412      00           AD  ...            False
# 1            F    202412      00           AE  ...            False
# 2            F    202412      00           AG  ...            False
# 3            F    202412      00           AI  ...            False
# 4            F    202412      00           AL  ...            False
# ...        ...       ...     ...          ...  ...              ...
# 2456285      F    201406  A12123           US  ...             True
# 2456286      F    201406  A12123           VN  ...             True
# 2456287      F    201406  A12123           VU  ...             True
# 2456288      F    201406  A12123           WS  ...             True
# 2456289      F    201406  A12123           ZA  ...             True
#
#          account_Imports product_type_Services product_type_Services  \
# 0                  False                 False                 False
# 1                  False                 False                 False
# 2                  False                 False                 False
# 3                  False                 False                 False
# 4                  False                 False                 False
# ...                  ...                   ...                   ...
# 2456285             True                  True                  True
# 2456286             True                  True                  True
# 2456287             True                  True                  True
# 2456288             True                  True                  True
# 2456289             True                  True                  True
#
#         product_type_Services product_type_Services product_type_Services  \
# 0                       False                 False                 False
# 1                       False                 False                 False
# 2                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# ...                       ...                   ...                   ...
# 2456285                  True                  True                  True
# 2456286                  True                  True                  True
# 2456287                  True                  True                  True
# 2456288                  True                  True                  True
# 2456289                  True                  True                  True
#
#         product_type_Services product_type_Services product_type_Services
# 0                       False                 False                 False
# 1                       False                 False                 False
# 2                       False                 False                 False
# 3                       False                 False                 False
# 4                       False                 False                 False
# ...                       ...                   ...                   ...
# 2456285                  True                  True                  True
# 2456286                  True                  True                  True
# 2456287                  True                  True                  True
# 2456288                  True                  True                  True
# 2456289                  True                  True                  True
#
# [2456290 rows x 112 columns]

# %%
print(modeldata['status'].describe()) #3 unique values. Can be hot coded
# Out:
#          status   status   status   status   status   status   status  \
# count   2456290  2456290  2456290  2456290  2456290  2456290  2456290
# unique        3        3        3        3        3        3        3
# top           F        F        F        F        F        F        F
# freq    2282345  2282345  2282345  2282345  2282345  2282345  2282345
#
#          status   status   status   status   status   status   status  \
# count   2456290  2456290  2456290  2456290  2456290  2456290  2456290
# unique        3        3        3        3        3        3        3
# top           F        F        F        F        F        F        F
# freq    2282345  2282345  2282345  2282345  2282345  2282345  2282345
#
#          status   status
# count   2456290  2456290
# unique        3        3
# top           F        F
# freq    2282345  2282345

# %%
modeldata_encoded = pd.get_dummies(modeldata, columns=['status'], drop_first=True) #encode account one hot
modeldata = pd.concat([modeldata, modeldata_encoded], axis=1) # merge unencoded and encoded dataframe
modeldata
# Out:
#          time_ref  account    code country_code product_type        value  \
# 0          202412  Exports      00           AD        Goods       2581.0
# 1          202412  Exports      00           AE        Goods  323384662.0
# 2          202412  Exports      00           AG        Goods     266255.0
# 3          202412  Exports      00           AI        Goods      11760.0
# 4          202412  Exports      00           AL        Goods     639168.0
# ...           ...      ...     ...          ...          ...          ...
# 2456285    201406  Imports  A12123           US     Services     168141.0
# 2456286    201406  Imports  A12123           VN     Services     112094.0
# 2456287    201406  Imports  A12123           VU     Services      56047.0
# 2456288    201406  Imports  A12123           WS     Services      56047.0
# 2456289    201406  Imports  A12123           ZA     Services      56047.0
#
#         status  time_ref    code country_code  ...  status_F status_R  \
# 0            F    202412      00           AD  ...      True    False
# 1            F    202412      00           AE  ...      True    False
# 2            F    202412      00           AG  ...      True    False
# 3            F    202412      00           AI  ...      True    False
# 4            F    202412      00           AL  ...      True    False
# ...        ...       ...     ...          ...  ...       ...      ...
# 2456285      F    201406  A12123           US  ...      True    False
# 2456286      F    201406  A12123           VN  ...      True    False
# 2456287      F    201406  A12123           VU  ...      True    False
# 2456288      F    201406  A12123           WS  ...      True    False
# 2456289      F    201406  A12123           ZA  ...      True    False
#
#          status_F status_R  status_F status_R  status_F status_R  status_F  \
# 0            True    False      True    False      True    False      True
# 1            True    False      True    False      True    False      True
# 2            True    False      True    False      True    False      True
# 3            True    False      True    False      True    False      True
# 4            True    False      True    False      True    False      True
# ...           ...      ...       ...      ...       ...      ...       ...
# 2456285      True    False      True    False      True    False      True
# 2456286      True    False      True    False      True    False      True
# 2456287      True    False      True    False      True    False      True
# 2456288      True    False      True    False      True    False      True
# 2456289      True    False      True    False      True    False      True
#
#         status_R
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 2456285    False
# 2456286    False
# 2456287    False
# 2456288    False
# 2456289    False
#
# [2456290 rows x 240 columns]

# %%
print(modeldata.isnull().sum())
# Out:
# time_ref             0
# account              0
# code                 0
# country_code      1578
# product_type         0
# value           151967
# status               0
# dtype: int64

# %%
print(modeldata['value'].mean())
# Out:
# 5096921.459327577

# %%
modeldata['value'] = modeldata['value'].fillna(modeldata['value'].mean())

# %%
print(modeldata.isnull())
# Out:
#          time_ref  account   code  country_code  product_type  value  status
# 0           False    False  False         False         False  False   False
# 1           False    False  False         False         False  False   False
# 2           False    False  False         False         False  False   False
# 3           False    False  False         False         False  False   False
# 4           False    False  False         False         False  False   False
# ...           ...      ...    ...           ...           ...    ...     ...
# 2456285     False    False  False         False         False  False   False
# 2456286     False    False  False         False         False  False   False
# 2456287     False    False  False         False         False  False   False
# 2456288     False    False  False         False         False  False   False
# 2456289     False    False  False         False         False  False   False
#
# [2456290 rows x 7 columns]

# %%
print(modeldata.isnull().sum())
# Out:
# time_ref           0
# account            0
# code               0
# country_code    1578
# product_type       0
# value              0
# status             0
# dtype: int64

# %%
modeldata
# Out:
#          time_ref  account    code country_code product_type        value  \
# 0          202412  Exports      00           AD        Goods       2581.0
# 1          202412  Exports      00           AE        Goods  323384662.0
# 2          202412  Exports      00           AG        Goods     266255.0
# 3          202412  Exports      00           AI        Goods      11760.0
# 4          202412  Exports      00           AL        Goods     639168.0
# ...           ...      ...     ...          ...          ...          ...
# 2456285    201406  Imports  A12123           US     Services     168141.0
# 2456286    201406  Imports  A12123           VN     Services     112094.0
# 2456287    201406  Imports  A12123           VU     Services      56047.0
# 2456288    201406  Imports  A12123           WS     Services      56047.0
# 2456289    201406  Imports  A12123           ZA     Services      56047.0
#
#         status  time_ref    code country_code  ...  product_type_Services  \
# 0            F    202412      00           AD  ...                  False
# 1            F    202412      00           AE  ...                  False
# 2            F    202412      00           AG  ...                  False
# 3            F    202412      00           AI  ...                  False
# 4            F    202412      00           AL  ...                  False
# ...        ...       ...     ...          ...  ...                    ...
# 2456285      F    201406  A12123           US  ...                   True
# 2456286      F    201406  A12123           VN  ...                   True
# 2456287      F    201406  A12123           VU  ...                   True
# 2456288      F    201406  A12123           WS  ...                   True
# 2456289      F    201406  A12123           ZA  ...                   True
#
#          product_type_Services  status_F status_R  status_F status_R  \
# 0                        False      True    False      True    False
# 1                        False      True    False      True    False
# 2                        False      True    False      True    False
# 3                        False      True    False      True    False
# 4                        False      True    False      True    False
# ...                        ...       ...      ...       ...      ...
# 2456285                   True      True    False      True    False
# 2456286                   True      True    False      True    False
# 2456287                   True      True    False      True    False
# 2456288                   True      True    False      True    False
# 2456289                   True      True    False      True    False
#
#          status_F status_R  status_F status_R
# 0            True    False      True    False
# 1            True    False      True    False
# 2            True    False      True    False
# 3            True    False      True    False
# 4            True    False      True    False
# ...           ...      ...       ...      ...
# 2456285      True    False      True    False
# 2456286      True    False      True    False
# 2456287      True    False      True    False
# 2456288      True    False      True    False
# 2456289      True    False      True    False
#
# [2456290 rows x 60 columns]
